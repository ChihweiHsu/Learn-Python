# %% [markdown]
# ## 作業
# 在鐵達尼資料集中，今天我們專注觀察變數之間的相關性，以Titanic_train.csv 中，首先將有遺失值的數值刪除，並回答下列問題。
# * Q1: 透過數值法計算  Age 和  Survived  是否有相關性?
# * Q2:透過數值法計算  Sex 和 Survived  是否有相關性?
# * Q3: 透過數值法計算  Age 和  Fare 是否有相關性?
# * 提示:
# 1.產稱一個新的變數 Survived_cate ，資料型態傳換成類別型態
# 2.把題目中的 Survived 用 Survived_cate 來做分析
# 3.首先觀察一下這些變數的資料型態後，再來想要以哪一種判斷倆倆的相關性。

# %%
# import library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics
import seaborn as sns
from IPython.display import display

import pingouin as pg
import researchpy   
# %matplotlib inline

# %% [markdown]
# ## 讀入資料

# %%
df_train = pd.read_csv("Titanic_train.csv")
print(df_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %%
display(df_train)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data = pd.DataFrame(df_train,columns=['Survived','Sex','Age','Fare'])#複製一份資料給 data

# %%
## 這邊我們做一個調整，把 Survived 變成離散型變數 Survived_cate
cat_features = []
for dtype, feature in zip(data.dtypes, data.columns):
    if dtype == 'object':
        cat_features.append(feature)
print(f'{len(cat_features)} category Features : {cat_features}\n')
# Out:
# 1 category Features : ['Sex']

# %% [markdown]
# ###  Q1: 透過數值法計算  Age 和  Survived  是否有相關性?

# %%
contTable = pd.crosstab(data['Age'], data['Survived'])
contTable
# Out:
# Survived  0  1
# Age
# 0.42      0  1
# 0.67      0  1
# 0.75      0  2
# 0.83      0  2
# 0.92      0  1
# ...      .. ..
# 70.00     2  0
# 70.50     1  0
# 71.00     2  0
# 74.00     1  0
# 80.00     0  1
#
# [88 rows x 2 columns]

# %%
df = min(contTable.shape[0], contTable.shape[1]) - 1
df
# Out:
# 1

# %%
crosstab, res = researchpy.crosstab(data['Age'], data['Survived'], test='chi-square')
print(res)
print("Cramer's value is",res.loc[2,'results'])
# Out:
#                  Chi-square test   results
# 0  Pearson Chi-square ( 87.0) =   104.1560
# 1                     p-value =     0.1014
# 2                  Cramer's V =     0.3819
# Cramer's value is 0.3819

# %%
## 寫一個副程式判斷相關性的強度
def judgment_CramerV(df,V):
    if df == 1:
        if V < 0.10:
            qual = 'negligible'
        elif V < 0.30:
            qual = 'small'
        elif V < 0.50:
            qual = 'medium'
        else:
            qual = 'large'
    elif df == 2:
        if V < 0.07:
            qual = 'negligible'
        elif V < 0.21:
            qual = 'small'
        elif V < 0.35:
            qual = 'medium'
        else:
            qual = 'large'
    elif df == 3:
        if V < 0.06:
            qual = 'negligible'
        elif V < 0.17:
            qual = 'small'
        elif V < 0.29:
            qual = 'medium'
        else:
            qual = 'large'
    elif df == 4:
        if V < 0.05:
            qual = 'negligible'
        elif V < 0.15:
            qual = 'small'
        elif V < 0.25:
            qual = 'medium'
        else:
            qual = 'large'
    else:
        if V < 0.05:
            qual = 'negligible'
        elif V < 0.13:
            qual = 'small'
        elif V < 0.22:
            qual = 'medium'
        else:
            qual = 'large'
    return(qual)

judgment_CramerV(df,res.loc[2,'results'])
# Out:
# 'medium'

# %% [markdown]
# ### 結論: 年齡和倖存這兩個變數，呈現中度相關

# %% [markdown]
# ### Q2:透過數值法計算  Sex 和 Survived  是否有相關性?

# %%
contTable_2 = pd.crosstab(data['Sex'], data['Survived'])
contTable_2
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
df = min(contTable_2.shape[0], contTable_2.shape[1]) - 1
df
# Out:
# 1

# %%
crosstab, res_2 = researchpy.crosstab(data['Sex'], data['Survived'], test='chi-square')
print(res_2)
print("Cramer's value is",res_2.loc[2,'results'])
# Out:
#                 Chi-square test   results
# 0  Pearson Chi-square ( 1.0) =   263.0506
# 1                    p-value =     0.0000
# 2               Cramer's phi =     0.5434
# Cramer's value is 0.5434

# %%
## 寫一個副程式判斷相關性的強度
def judgment_CramerV(df,V):
    if df == 1:
        if V < 0.10:
            qual = 'negligible'
        elif V < 0.30:
            qual = 'small'
        elif V < 0.50:
            qual = 'medium'
        else:
            qual = 'large'
    elif df == 2:
        if V < 0.07:
            qual = 'negligible'
        elif V < 0.21:
            qual = 'small'
        elif V < 0.35:
            qual = 'medium'
        else:
            qual = 'large'
    elif df == 3:
        if V < 0.06:
            qual = 'negligible'
        elif V < 0.17:
            qual = 'small'
        elif V < 0.29:
            qual = 'medium'
        else:
            qual = 'large'
    elif df == 4:
        if V < 0.05:
            qual = 'negligible'
        elif V < 0.15:
            qual = 'small'
        elif V < 0.25:
            qual = 'medium'
        else:
            qual = 'large'
    else:
        if V < 0.05:
            qual = 'negligible'
        elif V < 0.13:
            qual = 'small'
        elif V < 0.22:
            qual = 'medium'
        else:
            qual = 'large'
    return(qual)

judgment_CramerV(df,res_2.loc[2,'results'])
# Out:
# 'large'

# %% [markdown]
# ### 結論: 性別和倖存這兩個變數，呈現高度相關

# %% [markdown]
# ### Q3: 透過數值法計算  Age 和  Fare 是否有相關性?

# %%
contTable_3 = pd.crosstab(data['Age'], data['Fare'])
contTable_3
# Out:
# Fare   0.0000    4.0125    5.0000    6.2375    6.4375    6.4500    6.4958    \
# Age
# 0.42          0         0         0         0         0         0         0
# 0.67          0         0         0         0         0         0         0
# 0.75          0         0         0         0         0         0         0
# 0.83          0         0         0         0         0         0         0
# 0.92          0         0         0         0         0         0         0
# ...         ...       ...       ...       ...       ...       ...       ...
# 70.00         0         0         0         0         0         0         0
# 70.50         0         0         0         0         0         0         0
# 71.00         0         0         0         0         0         0         0
# 74.00         0         0         0         0         0         0         0
# 80.00         0         0         0         0         0         0         0
#
# ...

# %%
g = sns.regplot(x="Age", y="Fare", color="g",data=data)

# %%
aov = pg.anova(dv='Fare', between='Age', data=data, detailed=True)
aov
# Out:
#    Source            SS   DF           MS         F     p-unc       np2
# 0     Age  2.191248e+05   87  2518.675729  0.886992  0.754387  0.109744
# 1  Within  1.777570e+06  626  2839.568293       NaN       NaN       NaN

# %%
etaSq = aov.SS[0] / (aov.SS[0] + aov.SS[1])
etaSq
# Out:
# 0.1097437710238471

# %%
def judgment_etaSq(etaSq):
    if etaSq < .01:
        qual = 'Negligible'
    elif etaSq < .06:
        qual = 'Small'
    elif etaSq < .14:
        qual = 'Medium'
    else:
        qual = 'Large'
    return(qual)
judgment_etaSq(etaSq)
# Out:
# 'Medium'

# %% [markdown]
# ### 結論: 年齡和票價有中度相關性。
